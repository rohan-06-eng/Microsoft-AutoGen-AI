# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_agentchat.messages import TextMessage
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv('OPENAI_API_KEY')
model_client = OpenAIChatCompletionClient(model='gpt-4o', api_key=api_key)

# %%
async def web_search(query: str) -> str:
    """Find information on the web"""
    return "The Labrador Retriever or simply Labrador is a British breed of retriever gun dog. "

# %%
agent = AssistantAgent(
    name='assistant',
    model_client=model_client,
    tools=[web_search],
    system_message='Use Tools to solve tasks'
)

# %%
result = await agent.run(task='Find information about Labrador Retriever')
print(result.messages[-1].content)
# Out:
# The Labrador Retriever or simply Labrador is a British breed of retriever gun dog.

# %% [markdown]
# ### On_message() method

# %%
from autogen_core import CancellationToken

async def assistant_run()-> None:
    response = await agent.on_messages(
        messages= [TextMessage(content='Find information about Labrador Retriever',source='User')],
        cancellation_token=CancellationToken()
    )

    print(response.inner_messages)
    print('\n\n\n\n')
    print(response.chat_message)

await assistant_run()
# Out:
# [ToolCallRequestEvent(id='fe9b77fb-9300-40f3-9f78-8d477968d62f', source='assistant', models_usage=RequestUsage(prompt_tokens=114, completion_tokens=18), metadata={}, created_at=datetime.datetime(2025, 7, 31, 6, 1, 30, 219565, tzinfo=datetime.timezone.utc), content=[FunctionCall(id='call_9Ztg55HAMCJQd7ytCMeLVQMJ', arguments='{"query":"Labrador Retriever information"}', name='web_search')], type='ToolCallRequestEvent'), ToolCallExecutionEvent(id='987a56b1-a27a-4ccc-a845-a26b01b8bdf6', source='assistant', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 7, 31, 6, 1, 30, 219565, tzinfo=datetime.timezone.utc), content=[FunctionExecutionResult(content='The Labrador Retriever or simply Labrador is a British breed of retriever gun dog. ', name='web_search', call_id='call_9Ztg55HAMCJQd7ytCMeLVQMJ', is_error=False)], type='ToolCallExecutionEvent')]
#
#
#
#
#
# id='f65b7a93-8f52-4c9b-9dc9-968c91d28def' source='assistant' models_usage=None metadata={} created_at=datetime.datetime(2025, 7, 31, 6, 1, 30, 219565, tzinfo=datetime.timezone.utc) content='The Labrador Retriever or simply Labrador is a British breed of retriever gun dog. ' type='ToolCallSummaryMessage' tool_calls=[FunctionCall(id='call_9Ztg55HAMCJQd7ytCMeLVQMJ', arguments='{"query":"Labrador Retriever information"}', name='web_search')] results=[FunctionExecutionResult(content='The Labrador Retriever or simply Labrador is a British breed of retriever gun dog. ', name='web_search', call_id='call_9Ztg55HAMCJQd7ytCMeLVQMJ', is_error=False)]

# %%
from autogen_core import CancellationToken

async def assistant_run()-> None:
    response = await agent.on_messages(
        messages= [TextMessage(content='Find information about Labrador Retriever via the tool',source='User')],
        cancellation_token=CancellationToken()
    )

    print(response.inner_messages)
    print('\n\n\n\n')
    print(response.chat_message)

await assistant_run()
# Out:
# [ToolCallRequestEvent(id='9d295488-974d-4e90-a2ef-b442f448d029', source='assistant', models_usage=RequestUsage(prompt_tokens=171, completion_tokens=18), metadata={}, created_at=datetime.datetime(2025, 7, 31, 6, 2, 5, 900379, tzinfo=datetime.timezone.utc), content=[FunctionCall(id='call_P6dzkUUuyJ4i7MBqkJgrO8ff', arguments='{"query":"Labrador Retriever information"}', name='web_search')], type='ToolCallRequestEvent'), ToolCallExecutionEvent(id='a7ace077-4071-4c0a-a2f3-ef44afc7acdf', source='assistant', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 7, 31, 6, 2, 5, 901693, tzinfo=datetime.timezone.utc), content=[FunctionExecutionResult(content='The Labrador Retriever or simply Labrador is a British breed of retriever gun dog. ', name='web_search', call_id='call_P6dzkUUuyJ4i7MBqkJgrO8ff', is_error=False)], type='ToolCallExecutionEvent')]
#
#
#
#
#
# id='2c49d15a-ac6a-49da-b3e0-83dc0f895d1a' source='assistant' models_usage=None metadata={} created_at=datetime.datetime(2025, 7, 31, 6, 2, 5, 901693, tzinfo=datetime.timezone.utc) content='The Labrador Retriever or simply Labrador is a British breed of retriever gun dog. ' type='ToolCallSummaryMessage' tool_calls=[FunctionCall(id='call_P6dzkUUuyJ4i7MBqkJgrO8ff', arguments='{"query":"Labrador Retriever information"}', name='web_search')] results=[FunctionExecutionResult(content='The Labrador Retriever or simply Labrador is a British breed of retriever gun dog. ', name='web_search', call_id='call_P6dzkUUuyJ4i7MBqkJgrO8ff', is_error=False)]

# %% [markdown]
# ### Streaming Messages
#
# #### on_messages_stream()

# %%
from autogen_agentchat.ui import Console


async def assistant_run_stream() -> None:

    await Console(
        agent.on_messages_stream(
        messages= [TextMessage(content='Find information about Labrador Retriever via the tool',source='User')],
        cancellation_token=CancellationToken()
    ),
    output_stats=True # Enable stats Printing
    )


await assistant_run_stream()
# Out:
# ---------- ToolCallRequestEvent (assistant) ----------
# [FunctionCall(id='call_nLZOibJSkupLvSzch30WyIUx', arguments='{"query":"Labrador Retriever information"}', name='web_search')]
# [Prompt tokens: 228, Completion tokens: 18]
# ---------- ToolCallExecutionEvent (assistant) ----------
# [FunctionExecutionResult(content='The Labrador Retriever or simply Labrador is a British breed of retriever gun dog. ', name='web_search', call_id='call_nLZOibJSkupLvSzch30WyIUx', is_error=False)]
# ---------- assistant ----------
# The Labrador Retriever or simply Labrador is a British breed of retriever gun dog.
# ---------- Summary ----------
# Number of inner messages: 2
# Total prompt tokens: 228
# Total completion tokens: 18
# Duration: 0.61 seconds
